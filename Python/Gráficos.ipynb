# %% [markdown]
# # Histogramas
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('datasets/trees.csv')
data.shape
# Out:
# (31, 3)

# %%
data.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Gerando os dados com a coluna Height com Numpy
h = np.histogram(data.iloc[:,1], bins=6)
h
# Out:
# (array([4, 2, 5, 7, 9, 4], dtype=int64),
#  array([63., 67., 71., 75., 79., 83., 87.]))

# %%
# Visualização
plt.hist(data.iloc[:,1], bins=6)
plt.title('Árvores')
plt.ylabel('Frequência')
plt.xlabel('Altura');

# %% [markdown]
# # Aplicando linha de densidade
# ---

# %%
# Histograma com linhas  d ditribuição de frquência com 6 divisões 
sns.distplot(data.iloc[:,1], 
             hist=True, 
             kde=False,
             bins=6,
             color='blue',
             hist_kws=({'edgecolor': 'black'})
             );

# %%
# Linha Densidade 
sns.distplot(data.iloc[:,1], 
             hist=False, 
             kde=True,
             bins=6,
             color='blue',
             hist_kws=({'edgecolor': 'black'})
             );

# %%
sns.distplot(data.iloc[:,1], 
             hist=True, 
             kde=True,
             bins=6,
             color='blue',
             hist_kws=({'edgecolor': 'black'})
             );

# %% [markdown]
# # Gráfico de Dispersão
# ---

# %%
plt.scatter(data.Girth, data.Volume, color='blue', facecolors='none', marker='*')
plt.title('Árvore')
plt.xlabel('Volume')
plt.ylabel('Circunstância');

# %%
plt.plot(data.Girth, data.Volume)
plt.title('Árvore')
plt.xlabel('Volume')
plt.ylabel('Circunstância');

# %%
# Utilizando Seaborn com 'afastamento' dos dados (jitter)
sns.regplot(
    data.Girth,
    data.Volume,
    data=data,
    x_jitter=0.3,
    fit_reg= False
);

# %% [markdown]
# # Gráfico de Dispersão Com Legendas
# ---

# %%
data2 = pd.read_csv('datasets/co2.csv')
data2.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
x = data2.conc
y = data2.uptake

# %%
unicos = list(set(data2.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
for i in range(len(unicos)):
    ind = data.Treatment == unicos[i]
    plt.scatter(x[ind], y[ind], label = unicos[i])
plt.legend(loc = 'lower right');

# %% [markdown]
# # Divisão da Tela
# ---

# %%
plt.scatter(data.Girth, data.Volume);

# %%
plt.scatter(data.Girth, data.Height);

# %%
plt.scatter(data.Height, data.Volume, marker='*');

# %%
plt.hist(data.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(1)
plt.subplot(2,2,1)
plt.scatter(data.Girth, data.Volume);
plt.subplot(2,2,2)
plt.scatter(data.Girth, data.Height);
plt.subplot(2,2,3)
plt.scatter(data.Height, data.Volume, marker='*');
plt.subplot(2,2,4)
plt.hist(data.Volume);

# %% [markdown]
# # Boxplot
# ---

# %%
plt.boxplot(data.Volume, 
            vert=False,
            showfliers=False, #Outlies
            notch=True, #Entalhe
            patch_artist=True # Cor
            )
plt.title('Árvore')
plt.xlabel('Volume');

# %%
# Um boxplot para cada linha
plt.boxplot(data)
plt.title('Árvore')
plt.xlabel('Dados');

# %%
plt.boxplot(data.Volume, vert=False)
plt.boxplot(data.Girth, vert=False)
plt.boxplot(data.Height, vert=False)
plt.title('Árvore')
plt.xlabel('Dados');

# %%
data.boxplot(column=['Girth', 'Height', 'Volume'], showfliers=False, grid=False)
plt.show()

# %% [markdown]
# # Gráficos de Barras e Setores
# ---

# %%
data3 = pd.read_csv('datasets/insect.csv')
data3.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
data3.shape
# Out:
# (72, 2)

# %%
group = data3.groupby(['spray'])['count'].sum()
group
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
group.plot.bar(color='gray');

# %%
group.plot.bar(color=['blue','yellow','red','green','pink','orange']);

# %%
group.plot.pie();

# %%
group.plot.pie(legend=True);

# %% [markdown]
# # BoxPlot com Seaborn
# ---

# %%
sns.boxplot(data.Volume).set_title('Árvore');

# %%
sns.boxplot(data = data);

# %% [markdown]
# # Histogramas e Densidade com Seaborn
# ---

# %%
sns.distplot(data.Volume, 
             bins=10, 
             axlabel='Volume'
            ).set_title('Árvore');

# %%
data4 = pd.read_csv('datasets/chicken.csv')
data4.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
group = data4.groupby(['feed'])['weight'].sum()
group
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
test = data4.loc[data4['feed'] == 'horsebean']
test
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
sns.distplot(data4.loc[data4['feed'] == 'horsebean'].weight, 
             hist=False).set_title('horsebean');

# %%
sns.distplot(data4.loc[data4['feed'] == 'casein'].weight, 
             hist=False).set_title('casein');

# %%
sns.distplot(data4.loc[data4['feed'] == 'linseed'].weight, 
             hist=False).set_title('linseed');

# %%
sns.distplot(data4.loc[data4['feed'] == 'meatmeal'].weight, 
             hist=False).set_title('meatmeal');

# %%
sns.distplot(data4.loc[data4['feed'] == 'soybean'].weight, 
             hist=False).set_title('soybean');

# %%
sns.distplot(data4.loc[data4['feed'] == 'sunflower'].weight, 
             hist=False).set_title('sunflower');

# %%
plt.figure()
plt.subplot(3,2,1)
sns.distplot(data4.loc[data4['feed'] == 'horsebean'].weight, 
             hist=False).set_title('horsebean');
plt.subplot(3,2,2)
sns.distplot(data4.loc[data4['feed'] == 'casein'].weight, 
             hist=False).set_title('casein');
plt.subplot(3,2,3)
sns.distplot(data4.loc[data4['feed'] == 'linseed'].weight, 
             hist=False).set_title('linseed');
plt.subplot(3,2,4)
sns.distplot(data4.loc[data4['feed'] == 'meatmeal'].weight, 
             hist=False).set_title('meatmeal');
plt.subplot(3,2,5)
sns.distplot(data4.loc[data4['feed'] == 'soybean'].weight, 
             hist=False).set_title('soybean');
plt.subplot(3,2,6)
sns.distplot(data4.loc[data4['feed'] == 'sunflower'].weight, 
             hist=False).set_title('sunflower');
plt.tight_layout()

# %% [markdown]
# # Gráfico de Dispersão com Seaborn
# ---

# %%
data2.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
sns.scatterplot(data2.conc, data2.uptake, hue=data2.Type);

# %%
q = data2.loc[data2['Type'] == 'Quebec']
m = data2.loc[data2['Type'] == 'Mississippi']

# %%
plt.figure()
plt.subplot(1,2,1)
sns.scatterplot(q.conc, q.uptake).set_title('Quebec')
plt.subplot(1,2,2)
sns.scatterplot(m.conc, m.uptake).set_title('Mississippi')
plt.tight_layout()

# %%
a = data2.loc[data2['Treatment'] == 'chilled']
b = data2.loc[data2['Treatment'] == 'nonchilled']

# %%
plt.figure()
plt.subplot(1,2,1)
sns.scatterplot(a.conc, a.uptake).set_title('Chilled')
plt.subplot(1,2,2)
sns.scatterplot(b.conc, b.uptake).set_title('Nonchilled')
plt.tight_layout()

# %%
data5 = pd.read_csv('datasets/esoph.csv')
data5.head()
# Out:
#    agegp      alcgp     tobgp  ncases  ncontrols
# 0  25-34  0-39g/day  0-9g/day       0         40
# 1  25-34  0-39g/day     10-19       0         10
# 2  25-34  0-39g/day     20-29       0          6
# 3  25-34  0-39g/day       30+       0          5
# 4  25-34      40-79  0-9g/day       0         27

# %%
sns.catplot(x='alcgp', y='ncontrols', data=data5,jitter=False);

# %%
sns.catplot(x='alcgp', y='ncontrols', data=data5,jitter=False, col='tobgp');

# %%
# Exemplo - Violin Plot
data = pd.read_csv('datasets/Usuarios.csv')
data.head()
# Out:
#    Unnamed: 0  N estado_civil      grau_instrucao  n_filhos  salario  \
# 0           1  1     solteiro  ensino fundamental       NaN     4.00
# 1           2  2       casado  ensino fundamental       1.0     4.56
# 2           3  3       casado  ensino fundamental       2.0     5.25
# 3           4  4     solteiro        ensino medio       NaN     5.73
# 4           5  5     solteiro  ensino fundamental       NaN     6.26
#
#    idade_anos  idade_meses reg_procedencia
# 0          26            3        interior
# 1          32           10         capital
# 2          36            5         capital
# 3          20           10           outra
# 4          40            7           outra

# %%
sns.violinplot(x='salario', data=data)
plt.show()
